# %%
import torch
import torchvision
from torchvision import transforms, datasets

x = torch.Tensor([5, 3]) #creates empty tensor
y = torch.Tensor([12, 5])

print(x*y)

a = torch.zeros([2, 12]) #creates zero tensor
b = torch.zeros([5, 3])

print(b)
print(b.shape) #shows shape of tensor
print(b.view([1, 15])) #reshapes tensor

train = datasets.MNIST("", train=True, download=True, 
                        transform=transforms.Compose([transforms.ToTensor()])) #downloading training set as tensor
test = datasets.MNIST("", train=False, download=True, 
                        transform=transforms.Compose([transforms.ToTensor()])) #downloading test set as tensor

trainset = torch.utils.data.DataLoader(train, batch_size=12, shuffle=True) #loading, batching, and shuffling training set
testset = torch.utils.data.DataLoader(test, batch_size=12, shuffle=True) #loading, batching, and shuffling test set
